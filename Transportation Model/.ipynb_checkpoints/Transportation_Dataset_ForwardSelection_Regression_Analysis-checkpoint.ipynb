# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\SEAN\\anaconda3\\envs\\Carbon_Cloud\\python.exe'

# %%
# Importing required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Creating a dataframe
transport_df = pd.read_csv("Transportation_Hash_Dummy_Encoded_Dataset.csv")
transport_df.tail()
# Out:
#           make     model  engine_size  cylinders  fuel_consumption_comb  \
# 7379  0.016793  0.000406          2.0          4                    9.4
# 7380  0.016793  0.002979          2.0          4                    9.9
# 7381  0.016793  0.002979          2.0          4                   10.3
# 7382  0.016793  0.001761          2.0          4                    9.9
# 7383  0.016793  0.001761          2.0          4                   10.7
#
#       vehicle_class_cluster1  vehicle_class_cluster2  vehicle_class_cluster3  \
# 7379                       0                       0                       1
# 7380                       0                       0                       1
# 7381                       0                       0                       1
# 7382                       0                       0                       0
# 7383                       0                       0                       0
#
#       vehicle_class_cluster4  vehicle_class_cluster5  vehicle_class_cluster6  \
# 7379                       0                       0                       0
# 7380                       0                       0                       0
# 7381                       0                       0                       0
# 7382                       0                       0                       1
# 7383                       0                       0                       1
#
#       transmission_AM  transmission_AS  transmission_AV  transmission_M  \
# 7379                0                1                0               0
# 7380                0                1                0               0
# 7381                0                1                0               0
# 7382                0                1                0               0
# 7383                0                1                0               0
#
#       fuel_type_E  fuel_type_X  fuel_type_Z  co2_emissions
# 7379            0            0            1            219
# 7380            0            0            1            232
# 7381            0            0            1            240
# 7382            0            0            1            232
# 7383            0            0            1            248

# %%
transport_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7384 entries, 0 to 7383
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   make                    7384 non-null   float64
#  1   model                   7384 non-null   float64
#  2   engine_size             7384 non-null   float64
#  3   cylinders               7384 non-null   int64
#  4   fuel_consumption_comb   7384 non-null   float64
#  5   vehicle_class_cluster1  7384 non-null   int64
#  6   vehicle_class_cluster2  7384 non-null   int64
#  7   vehicle_class_cluster3  7384 non-null   int64
#  8   vehicle_class_cluster4  7384 non-null   int64
#  9   vehicle_class_cluster5  7384 non-null   int64
#  10  vehicle_class_cluster6  7384 non-null   int64
#  11  transmission_AM         7384 non-null   int64
#  12  transmission_AS         7384 non-null   int64
#  13  transmission_AV         7384 non-null   int64
#  14  transmission_M          7384 non-null   int64
#  15  fuel_type_E             7384 non-null   int64
#  16  fuel_type_X             7384 non-null   int64
#  17  fuel_type_Z             7384 non-null   int64
#  18  co2_emissions           7384 non-null   int64
# dtypes: float64(4), int64(15)
# memory usage: 1.1 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import f

# %%
# Split the dataset into training and testing sets
train_df, test_df = train_test_split(transport_df, test_size=0.2, random_state=42)

# %%
# Forward Selection with only Independent Variables
# For variable to enter the model we set the p_value (Threshold value) to 0.05

# %%
# IQV => Independent Variables, DV => Dependent Variable
transport_df_IV_TO_DV = transport_df.drop(['co2_emissions'], axis=1)

# %%
def create_ANOVA(formula):

    # Fit the model using the formula
    model = ols(formula, data=train_df).fit()
    
    # Define the sum of squares for each source of variation
    SS_reg = np.sum((model.fittedvalues - np.mean(train_df['co2_emissions']))**2)  # Regression sum of squares
    SS_res = np.sum(model.resid**2)  # Residual sum of squares
    SS_tot = SS_reg + SS_res  # Total sum of squares
    
    # Calculate degrees of freedom
    n_obs = len(train_df)  # Number of observations
    k_params = len(model.params) - 1  # Number of parameters (excluding intercept)
    df_reg = k_params  # Degrees of freedom for regression
    df_res = n_obs - k_params - 1  # Degrees of freedom for residual
    df_tot = n_obs - 1  # Total degrees of freedom
    
    # Calculate mean squares
    MS_reg = SS_reg / df_reg  # Mean square for regression
    MS_res = SS_res / df_res  # Mean square for residual
    
    # Calculate F-value
    F_value = MS_reg / MS_res
    
    # Calculate p-value
    from scipy.stats import f
    p_value = 1 - f.cdf(F_value, df_reg, df_res)
    
    # Create the ANOVA table
    anova_table_manual = pd.DataFrame({
        '': ['Regression', 'Residual', 'Total'],
        'SS': [SS_reg, SS_res, SS_tot],
        'DF': [df_reg, df_res, df_tot],
        'MS': [MS_reg, MS_res, np.nan],  # No mean square for total row
        'F': [F_value, np.nan, np.nan],  # No F-value for total row
        'Pr(>F)': [p_value, np.nan, np.nan]  # No p-value for total row
    })
    
    # Print the ANOVA table
    # print(anova_table_manual)

    return anova_table_manual, SS_res, MS_res, df_res

def F_test(low_feature_SSE, SS_res, MS_res, features_added):
    f_test = ((low_feature_SSE - SS_res) / features_added) / MS_res
    return f_test

def P_value(f_test, features_added, df_res):
    # Calculate the right-tailed F probability distribution
    probability = 1 - f.cdf(f_test, features_added, df_res)
    return probability

# %%
for i in transport_df_IV_TO_DV.columns:
    formula = f'co2_emissions ~ {i}'
    anova_table_manual, SS_res, MS_res, df_res = create_ANOVA(formula)
    print(formula)
    print(anova_table_manual)
    print()
# Out:
# co2_emissions ~ make
#                          SS    DF             MS          F        Pr(>F)
# 0  Regression  1.452448e+05     1  145244.836698  42.894278  6.266088e-11
# 1    Residual  1.999499e+07  5905    3386.112205        NaN           NaN
# 2       Total  2.014024e+07  5906            NaN        NaN           NaN
#
# co2_emissions ~ model
#                          SS    DF            MS         F    Pr(>F)
# 0  Regression  1.197137e+04     1  11971.366376  3.512022  0.060974
# 1    Residual  2.012827e+07  5905   3408.681802       NaN       NaN
# 2       Total  2.014024e+07  5906           NaN       NaN       NaN
#
# co2_emissions ~ engine_size
#                          SS    DF            MS             F        Pr(>F)
# 0  Regression  1.460002e+07     1  1.460002e+07  15561.317481  1.110223e-16
# 1    Residual  5.540219e+06  5905  9.382251e+02           NaN           NaN
# 2       Total  2.014024e+07  5906           NaN           NaN           NaN
#
# co2_emissions ~ cylinders
#                          SS    DF            MS             F        Pr(>F)
# 0  Regression  1.395188e+07     1  1.395188e+07  13313.024791  1.110223e-16
# 1    Residual  6.188362e+06  5905  1.047987e+03           NaN           NaN
# 2       Total  2.014024e+07  5906           NaN           NaN           NaN
#
# co2_emissions ~ fuel_consumption_comb
#                          SS    DF            MS             F        Pr(>F)
# 0  Regression  1.695132e+07     1  1.695132e+07  31389.216091  1.110223e-16
# 1    Residual  3.188915e+06  5905  5.400365e+02           NaN           NaN
# 2       Total  2.014024e+07  5906           NaN           NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster1
#                          SS    DF             MS         F        Pr(>F)
# 0  Regression  1.767592e+05     1  176759.173538  52.28362  5.413447e-13
# 1    Residual  1.996348e+07  5905    3380.775315       NaN           NaN
# 2       Total  2.014024e+07  5906            NaN       NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster2
#                          SS    DF             MS          F        Pr(>F)
# 0  Regression  1.080409e+05     1  108040.920887  31.847813  1.744893e-08
# 1    Residual  2.003220e+07  5905    3392.412614        NaN           NaN
# 2       Total  2.014024e+07  5906            NaN        NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster3
#                          SS    DF             MS           F        Pr(>F)
# 0  Regression  7.076771e+05     1  707677.145678  215.042871  1.110223e-16
# 1    Residual  1.943256e+07  5905    3290.865413         NaN           NaN
# 2       Total  2.014024e+07  5906            NaN         NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster4
#                          SS    DF            MS           F        Pr(>F)
# 0  Regression  1.059346e+06     1  1.059346e+06  327.837706  1.110223e-16
# 1    Residual  1.908089e+07  5905  3.231311e+03         NaN           NaN
# 2       Total  2.014024e+07  5906           NaN         NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster5
#                          SS    DF             MS          F        Pr(>F)
# 0  Regression  2.883972e+05     1  288397.236307  85.784777  1.110223e-16
# 1    Residual  1.985184e+07  5905    3361.869631        NaN           NaN
# 2       Total  2.014024e+07  5906            NaN        NaN           NaN
#
# co2_emissions ~ vehicle_class_cluster6
#                          SS    DF            MS            F        Pr(>F)
# 0  Regression  3.331209e+06     1  3.331209e+06  1170.251393  1.110223e-16
# 1    Residual  1.680903e+07  5905  2.846576e+03          NaN           NaN
# 2       Total  2.014024e+07  5906           NaN          NaN           NaN
#
# co2_emissions ~ transmission_AM
#                          SS    DF           MS         F    Pr(>F)
# 0  Regression  2.313499e+03     1  2313.498644  0.678382  0.410178
# 1    Residual  2.013792e+07  5905  3410.317343       NaN       NaN
# 2       Total  2.014024e+07  5906          NaN       NaN       NaN
#
# co2_emissions ~ transmission_AS
#                          SS    DF            MS          F        Pr(>F)
# 0  Regression  9.165940e+04     1  91659.401157  26.996865  2.106251e-07
# 1    Residual  2.004858e+07  5905   3395.186792        NaN           NaN
# 2       Total  2.014024e+07  5906           NaN        NaN           NaN
#
# co2_emissions ~ transmission_AV
#                          SS    DF            MS           F        Pr(>F)
# 0  Regression  2.235816e+06     1  2.235816e+06  737.387201  1.110223e-16
# 1    Residual  1.790442e+07  5905  3.032078e+03         NaN           NaN
# 2       Total  2.014024e+07  5906           NaN         NaN           NaN
#
# co2_emissions ~ transmission_M
#                          SS    DF             MS           F        Pr(>F)
# 0  Regression  5.629899e+05     1  562989.878936  169.812188  1.110223e-16
# 1    Residual  1.957725e+07  5905    3315.367913         NaN           NaN
# 2       Total  2.014024e+07  5906            NaN         NaN           NaN
#
# co2_emissions ~ fuel_type_E
#                          SS    DF             MS          F        Pr(>F)
# 0  Regression  1.915023e+05     1  191502.264540  56.686344  5.884182e-14
# 1    Residual  1.994874e+07  5905    3378.278602        NaN           NaN
# 2       Total  2.014024e+07  5906            NaN        NaN           NaN
#
# co2_emissions ~ fuel_type_X
#                          SS    DF            MS           F        Pr(>F)
# 0  Regression  1.388105e+06     1  1.388105e+06  437.110944  1.110223e-16
# 1    Residual  1.875213e+07  5905  3.175636e+03         NaN           NaN
# 2       Total  2.014024e+07  5906           NaN         NaN           NaN
#
# co2_emissions ~ fuel_type_Z
#                          SS    DF            MS           F        Pr(>F)
# 0  Regression  1.086646e+06     1  1.086646e+06  336.768312  1.110223e-16
# 1    Residual  1.905359e+07  5905  3.226688e+03         NaN           NaN
# 2       Total  2.014024e+07  5906           NaN         NaN           NaN

# %%
# So here the selected feature is "fuel_consumption_comb"

# Construct the formula string dynamically
formula = f'co2_emissions ~ fuel_consumption_comb'

# Fit the model using the formula
model = ols(formula, data=train_df).fit()

# Perform ANOVA analysis
anova_table = sm.stats.anova_lm(model, typ=2)
low_feature_SSE = anova_table.sum_sq['Residual']
print("low_feature_SSE : ", low_feature_SSE)
print()
print(anova_table)
# Out:
# low_feature_SSE :  3188915.4499986055
#
#                              sum_sq      df             F  PR(>F)
# fuel_consumption_comb  1.695132e+07     1.0  31389.216091     0.0
# Residual               3.188915e+06  5905.0           NaN     NaN

# %%
transport_df_IV_TO_DV = transport_df_IV_TO_DV.drop(['fuel_consumption_comb'], axis=1)

# %%
threshold_p_value = 0.05
formula = f'co2_emissions ~ fuel_consumption_comb'
p_value_list = []
SSE_reduction_list = []
p_value = 0.03

while ((p_value < threshold_p_value) and (transport_df_IV_TO_DV.shape[1] != 0)):

    for i in transport_df_IV_TO_DV.columns:
        anova_table_manual, SS_res, MS_res, df_res = create_ANOVA((formula + f' + {i}'))
        f_test = F_test(low_feature_SSE, SS_res, MS_res, 1)
        p_value = P_value(f_test, 1, df_res)
    
        p_value_list.append(p_value)
        SSE_reduction_list.append((low_feature_SSE - SS_res))

    sse_reduction_max = max(SSE_reduction_list)
    sse_reduction_max_index = SSE_reduction_list.index(sse_reduction_max)
    print("SSE Reduction : ", sse_reduction_max)
    
    # p_value_low = min(p_value_list)
    # print("p_value_low : ", p_value_low)
    
    # p_value_low_index = p_value_list.index(p_value_low)

    p_value = p_value_list[sse_reduction_max_index]
    print("P_value is : ", p_value)
    
    selected_column_name = transport_df_IV_TO_DV.columns[sse_reduction_max_index]
    print("Selected Column is : ", selected_column_name)

    if (p_value < threshold_p_value):
        formula = formula + f' + {selected_column_name}'
        print(formula)
        
        # Fit the model using the formula
        model = ols(formula, data=train_df).fit()
        # Perform ANOVA analysis
        anova_table = sm.stats.anova_lm(model, typ=2)
        low_feature_SSE = anova_table.sum_sq['Residual']
        print("low_feature_SSE : ", low_feature_SSE)
    
        transport_df_IV_TO_DV.drop([selected_column_name], axis=1, inplace=True)

    p_value_list.clear()
    SSE_reduction_list.clear()
    print()
# Out:
# SSE Reduction :  2886389.0614004945
# P_value is :  1.1102230246251565e-16
# Selected Column is :  fuel_type_E
# co2_emissions ~ fuel_consumption_comb + fuel_type_E
# low_feature_SSE :  302526.38859811093
#
# SSE Reduction :  9270.745099669148
# P_value is :  1.1102230246251565e-16
# Selected Column is :  vehicle_class_cluster4
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4
# low_feature_SSE :  293255.64349844184
#
# SSE Reduction :  5973.584553091612
# P_value is :  1.1102230246251565e-16
# Selected Column is :  vehicle_class_cluster1
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1
# low_feature_SSE :  287282.0589453502
#
# SSE Reduction :  4590.4612554971245
# P_value is :  1.1102230246251565e-16
# Selected Column is :  fuel_type_X
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X
# low_feature_SSE :  282691.597689853
#
# SSE Reduction :  120707.78282124305
# P_value is :  1.1102230246251565e-16
# Selected Column is :  fuel_type_Z
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z
# low_feature_SSE :  161983.81486860994
#
# SSE Reduction :  1400.1981029588496
# P_value is :  8.305578447220796e-13
# Selected Column is :  cylinders
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders
# low_feature_SSE :  160583.61676565115
#
# SSE Reduction :  927.14639433095
# P_value is :  5.106224665318848e-09
# Selected Column is :  transmission_AV
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV
# low_feature_SSE :  159656.47037132017
#
# SSE Reduction :  521.555197076028
# P_value is :  1.1206803926744335e-05
# Selected Column is :  vehicle_class_cluster2
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2
# low_feature_SSE :  159134.9151742441
#
# SSE Reduction :  521.5769586597162
# P_value is :  1.0855218999350491e-05
# Selected Column is :  transmission_M
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M
# low_feature_SSE :  158613.33821558434
#
# SSE Reduction :  431.52508255749126
# P_value is :  6.141556954031291e-05
# Selected Column is :  make
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M + make
# low_feature_SSE :  158181.81313302685
#
# SSE Reduction :  370.02929792911164
# P_value is :  0.00020305359916528154
# Selected Column is :  vehicle_class_cluster3
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M + make + vehicle_class_cluster3
# low_feature_SSE :  157811.7838350977
#
# SSE Reduction :  133.34325500609702
# P_value is :  0.0256274681043257
# Selected Column is :  model
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M + make + vehicle_class_cluster3 + model
# low_feature_SSE :  157678.4405800916
#
# SSE Reduction :  104.3109083805466
# P_value is :  0.04832163483732477
# Selected Column is :  transmission_AM
# co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M + make + vehicle_class_cluster3 + model + transmission_AM
# low_feature_SSE :  157574.12967171104
#
# SSE Reduction :  63.78170635647257
# P_value is :  0.12252086164536402
# Selected Column is :  vehicle_class_cluster6

# %%
# Find which Independent Variables are selected through the Forward Selection Technique.
formula
# Out:
# 'co2_emissions ~ fuel_consumption_comb + fuel_type_E + vehicle_class_cluster4 + vehicle_class_cluster1 + fuel_type_X + fuel_type_Z + cylinders + transmission_AV + vehicle_class_cluster2 + transmission_M + make + vehicle_class_cluster3 + model + transmission_AM'

# %%
# Find the missing columns in the model.
transport_df_IV_TO_DV.columns
# Out:
# Index(['engine_size', 'vehicle_class_cluster5', 'vehicle_class_cluster6',
#        'transmission_AS'],
#       dtype='object')

# %%
# Train the model with the selected features from Forward Selection Technique.

# Fit the model using the formula
model = ols(formula, data=train_df).fit()

# Perform ANOVA analysis
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                               sum_sq      df              F        PR(>F)
# fuel_consumption_comb   4.469257e+06     1.0  167114.137067  0.000000e+00
# fuel_type_E             1.339706e+06     1.0   50094.177419  0.000000e+00
# vehicle_class_cluster4  7.926947e+03     1.0     296.403815  7.560021e-65
# vehicle_class_cluster1  5.756550e+03     1.0     215.248482  6.826006e-48
# fuel_type_X             1.107196e+05     1.0    4140.020327  0.000000e+00
# fuel_type_Z             1.058588e+05     1.0    3958.264654  0.000000e+00
# cylinders               2.181819e+03     1.0      81.582401  2.239104e-19
# transmission_AV         1.180194e+03     1.0      44.129730  3.348883e-11
# vehicle_class_cluster2  6.128452e+02     1.0      22.915462  1.734196e-06
# transmission_M          4.633341e+02     1.0      17.324953  3.195122e-05
# make                    6.452994e+02     1.0      24.128985  9.252705e-07
# vehicle_class_cluster3  2.764786e+02     1.0      10.338067  1.310177e-03
# model                   1.542975e+02     1.0       5.769479  1.633764e-02
# transmission_AM         1.043109e+02     1.0       3.900386  4.832163e-02
# Residual                1.575741e+05  5892.0            NaN           NaN

# %%
# Viewing the model summary.
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          co2_emissions   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 5.337e+04
# Date:                Wed, 28 Feb 2024   Prob (F-statistic):               0.00
# Time:                        23:09:49   Log-Likelihood:                -18080.
# No. Observations:                5907   AIC:                         3.619e+04
# Df Residuals:                    5892   BIC:                         3.629e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 34.4182      0.548     62.761      0.000      33.343      35.493
# fuel_consumption_comb     22.5143      0.055    408.796      0.000      22.406      22.622
# fuel_type_E             -143.1807      0.640   -223.817      0.000    -144.435    -141.927
# vehicle_class_cluster4   -14.0658      0.817    -17.216      0.000     -15.667     -12.464
# vehicle_class_cluster1   -20.6820      1.410    -14.671      0.000     -23.445     -17.918
# fuel_type_X              -29.8539      0.464    -64.343      0.000     -30.764     -28.944
# fuel_type_Z              -29.8042      0.474    -62.915      0.000     -30.733     -28.876
# cylinders                  0.6697      0.074      9.032      0.000       0.524       0.815
# transmission_AV           -1.8650      0.281     -6.643      0.000      -2.415      -1.315
# vehicle_class_cluster2     1.9209      0.401      4.787      0.000       1.134       2.708
# transmission_M            -0.8125      0.195     -4.162      0.000      -1.195      -0.430
# make                      15.0538      3.065      4.912      0.000       9.046      21.062
# vehicle_class_cluster3     0.6028      0.187      3.215      0.001       0.235       0.970
# model                    -24.2549     10.098     -2.402      0.016     -44.050      -4.459
# transmission_AM           -0.4973      0.252     -1.975      0.048      -0.991      -0.004
# ==============================================================================
# Omnibus:                     1753.380   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           191310.265
# Skew:                          -0.337   Prob(JB):                         0.00
# Kurtosis:                      30.872   Cond. No.                     1.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Testing the Model.

from sklearn.metrics import mean_squared_error, r2_score

# Use the fitted model to make predictions on the testing data
predictions = model.predict(test_df)

# Calculate evaluation metrics
mse = mean_squared_error(test_df['co2_emissions'], predictions)
r2 = r2_score(test_df['co2_emissions'], predictions)

# Print the evaluation metrics
print("Mean Squared Error (MSE):", mse)
print("R-squared (R2):", r2)
# Out:
# Mean Squared Error (MSE): 27.19344677774547
# R-squared (R2): 0.992177663886706

# %%
# Plot Actual vs Predicted values
plt.figure(figsize=(10, 6))
sns.scatterplot(x=test_df['co2_emissions'], y=predictions)
plt.xlabel('Actual CO2 Emissions')
plt.ylabel('Predicted CO2 Emissions')
plt.title('Actual vs Predicted CO2 Emissions')
plt.show()

# %%
# Calculate residuals
residuals = test_df['co2_emissions'] - predictions

# Create the residual plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=test_df['co2_emissions'], y=residuals, color='blue')
# Adding a horizontal line at y=0
plt.axhline(y=0, color='red', linestyle='--')
plt.title('Residual Plot')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.show()
